# %% [markdown]
# # Digital image and signal processing

# %% [markdown]
# ## Exercise 8
#
# The aim of the exercise is to test the effectiveness of salt and pepper noise reduction by means of low-pass filtration.

# %% [markdown]
# ### Authors
#
# - Kinga Marek
# - Mariusz Wiśniewski

# %% [markdown]
# ### Libraries used

# %%
from skimage import io, filters
from matplotlib.pyplot import subplot, imshow, title, show, rcParams
from skimage.color import rgb2gray
rcParams['figure.figsize'] = [15, 10]

# %% [markdown]
# ### Loading an image

# %%
image = rgb2gray(io.imread('../data/images/lenna_noisy.jpg'))  # high noise image

# %% [markdown]
# ### Task 1
#
# Test the salt and pepper noise reduction efficiency with a square mask linear averaging filter, starting with a 3 × 3 size mask.

# %%
# a) averaging filters
gaussian3 = filters.gaussian(image, sigma=3)
gaussian5 = filters.gaussian(image, sigma=5)
gaussian7 = filters.gaussian(image, sigma=7)

subplot(141), imshow(image, cmap='gray'), title('Original')
subplot(142), imshow(gaussian3, cmap='gray'), title('Gaussian, sigma=3')
subplot(143), imshow(gaussian5, cmap='gray'), title('Gaussian, sigma=5')
subplot(144), imshow(gaussian7, cmap='gray'), title('Gaussian, sigma=7')
show()

# %% [markdown]
# It's easy to see the rule - the larger the size of the square mask, the greater the noise reduction or blurring of the image.

# %% [markdown]
# ### Task 2
#
# Test the effectiveness of salt and pepper noise reduction with a nonlinear median filter.

# %%
# b) median filter
median = filters.median(image)

subplot(121), imshow(image, cmap='gray'), title('Original')
subplot(122), imshow(median, cmap='gray'), title('Median filter applied')
show()
